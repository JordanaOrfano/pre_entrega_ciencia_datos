# %% [markdown]
# # 📘 Pre-entrega
#
# **Nombre del alumno:** Jordana Orfano

# %% [markdown]
# ## Etapa 1: Recopilación y Preparación de Datos

# %% [markdown]
# ### 1️⃣ Carga de datos

# %%
# Importar la librería Pandas y montar la unidad
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Verificar que los archivos csv se encuentren en la carpeta datasets
import os
os.listdir("/content/drive/MyDrive/datasets")
# Out:
# ['ventas.csv', 'clientes.csv', 'marketing.csv']

# %% [markdown]
# ### 2️⃣ Análisis exploratorio inicial

# %%
print("--------------------------- Clientes ---------------------------")
df_clientes = pd.read_csv("/content/drive/MyDrive/datasets/clientes.csv")
df_clientes.info()

print("\n--------------------------- Marketing ---------------------------")

df_marketing = pd.read_csv("/content/drive/MyDrive/datasets/marketing.csv")
df_marketing.info()

print("\n--------------------------- Ventas ---------------------------")

df_ventas = pd.read_csv("/content/drive/MyDrive/datasets/ventas.csv")
df_ventas.info()
# Out:
# --------------------------- Clientes ---------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567 entries, 0 to 566
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_cliente  567 non-null    int64
#  1   nombre      567 non-null    object
#  2   edad        567 non-null    int64
#  3   ciudad      567 non-null    object
#  4   ingresos    567 non-null    float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 22.3+ KB
#
# --------------------------- Marketing ---------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_campanha   90 non-null     int64
#  1   producto      90 non-null     object
#  2   canal         90 non-null     object
#  3   costo         90 non-null     float64
# ...

# %%
print("Marketing")
display(df_marketing.head(10))
print("\nVentas")
display(df_ventas.head(10))
print("\nClientes")
display(df_clientes.head(10))
# Out:
# Marketing
#    id_campanha             producto  canal  costo fecha_inicio   fecha_fin
# 0           74      Adorno de pared     TV   4.81   20/03/2024  03/05/2024
# 1           12               Tablet   RRSS   3.40   26/03/2024  13/05/2024
# 2           32      Lámpara de mesa  Email   5.54   28/03/2024  20/04/2024
# 3           21           Smartphone   RRSS   6.37   29/03/2024  16/05/2024
# 4           58             Alfombra  Email   4.25   31/03/2024  05/05/2024
# 5           85           SmartWatch     TV   5.07   01/04/2024  05/05/2024
# 6           36     Plancha de vapor  Email   5.41   02/04/2024  01/06/2024
# 7           57             Batidora  Email   4.48   10/04/2024  08/06/2024
# 8           44      Adorno de pared  Email   5.08   13/04/2024  10/05/2024
# 9           84  Parlantes Bluetooth     TV   4.42   17/04/2024  05/05/2024
# Ventas
#    id_venta           producto   precio  cantidad fecha_venta  \
# 0       792  Cuadro decorativo   $69.94       5.0  02/01/2024
# ...

# %%
print("Marketing")
display(df_marketing.describe())

print("\nVentas")
display(df_ventas.describe())

print("\nClientes")
display(df_clientes.describe())
# Out:
# Marketing
#        id_campanha      costo
# count    90.000000  90.000000
# mean     45.500000   4.928667
# std      26.124701   0.947750
# min       1.000000   2.950000
# 25%      23.250000   4.372500
# 50%      45.500000   4.900000
# 75%      67.750000   5.562500
# max      90.000000   7.390000
# Ventas
#           id_venta     cantidad
# count  3035.000000  3033.000000
# mean   1499.851400     6.496538
# std     866.465379     3.457250
# min       1.000000     1.000000
# 25%     748.500000     3.000000
# 50%    1502.000000     7.000000
# 75%    2249.500000     9.000000
# max    3000.000000    12.000000
# Clientes
#        id_cliente        edad      ingresos
# count  567.000000  567.000000    567.000000
# mean   284.000000   37.940035  34668.739012
# std    163.823075   10.202885  12974.531446
# min      1.000000   20.000000    170.290000
# 25%    142.500000   30.000000  26015.240000
# 50%    284.000000   37.000000  35066.830000
# 75%    425.500000   43.000000  42457.100000
# ...

# %% [markdown]
# ### 3️⃣ Calidad de los datos

# %%
print(f"Nulos de Clientes:\n{df_clientes.isnull().sum()}\n\n")
print(f"Nulos de Ventas:\n{df_ventas.isnull().sum()}\n\n")
print(f"Nulos de Marketing:\n{df_marketing.isnull().sum()}")
# Out:
# Nulos de Clientes:
# id_cliente    0
# nombre        0
# edad          0
# ciudad        0
# ingresos      0
# dtype: int64
#
#
# Nulos de Ventas:
# id_venta       0
# producto       0
# precio         2
# cantidad       2
# fecha_venta    0
# categoria      0
# dtype: int64
#
#
# Nulos de Marketing:
# id_campanha     0
# producto        0
# canal           0
# costo           0
# fecha_inicio    0
# fecha_fin       0
# dtype: int64

# %%
def detectar_duplicados(df, columna_clave, nombre_df):
    if columna_clave not in df.columns:
        print(f"\nLa columna clave '{columna_clave}' no existe en {nombre_df}.")
        return

    conteo = df[columna_clave].value_counts()

    duplicados = conteo[conteo > 1]

    print(f"\n--------------------------- {nombre_df} ---------------------------")
    print(f"Clave: {columna_clave}")

    if duplicados.empty:
        print("No se encontraron duplicados.")
    else:
        print(f"Se encontraron {len(duplicados)} duplicados.\n")
        print("Claves duplicadas y cantidad de repeticiones:")
        print(duplicados)


detectar_duplicados(df_clientes, "id_cliente", "Clientes")
detectar_duplicados(df_ventas, "id_venta", "Ventas")
detectar_duplicados(df_marketing, "id_campanha", "Marketing")
# Out:
# --------------------------- Clientes ---------------------------
# Clave: id_cliente
# No se encontraron duplicados.
#
# --------------------------- Ventas ---------------------------
# Clave: id_venta
# Se encontraron 35 duplicados.
#
# Claves duplicadas y cantidad de repeticiones:
# id_venta
# 2356    2
# 2096    2
# 2085    2
# 1956    2
# 1642    2
# 821     2
# 509     2
# 398     2
# 345     2
# 213     2
# 2169    2
# 2108    2
# 2080    2
# 2373    2
# 1784    2
# 1776    2
# 1376    2
# 959     2
# 906     2
# 439     2
# 300     2
# 145     2
# 2778    2
# 2545    2
# 1868    2
# 424     2
# 421     2
# 56      2
# 1974    2
# 1381    2
# 2365    2
# 2486    2
# 2506    2
# 2705    2
# 204     2
# Name: count, dtype: int64
#
# --------------------------- Marketing ---------------------------
# Clave: id_campanha
# No se encontraron duplicados.

# %% [markdown]
# # Etapa 2: Preprocesamiento y Limpieza de Datos

# %% [markdown]
# ### 4️⃣ Limpieza de datos

# %%
# COPIAS PARA TRABAJAR SIN MODIFICAR LOS ORIGINALES

clientes_limpio = df_clientes.copy()
ventas_limpio = df_ventas.copy()
marketing_limpio = df_marketing.copy()

# %% [markdown]
# #### Eliminación de duplicados

# %%
def eliminar_duplicados(df, nombre):
    print(f"\n--------------------------- {nombre} ---------------------------")
    filas_antes = len(df)
    dups = df.duplicated().sum()
    print(f"Filas antes: {filas_antes}")

    df_limpio = df.drop_duplicates()
    filas_despues = len(df_limpio)
    eliminadas = filas_antes - filas_despues

    print(f"Filas duplicadas eliminadas: {eliminadas}")
    return df_limpio

df_ventas = eliminar_duplicados(ventas_limpio, "Ventas")
df_clientes = eliminar_duplicados(clientes_limpio, "Clientes")
df_marketing= eliminar_duplicados(marketing_limpio,"Marketing")
# Out:
# --------------------------- Ventas ---------------------------
# Filas antes: 3035
# Filas duplicadas eliminadas: 35
#
# --------------------------- Clientes ---------------------------
# Filas antes: 567
# Filas duplicadas eliminadas: 0
#
# --------------------------- Marketing ---------------------------
# Filas antes: 90
# Filas duplicadas eliminadas: 0

# %% [markdown]
# #### Limpieza de texto

# %%
def normalizacion_texto(df, nombre_df):
    print(f"\n--------------------------- {nombre_df} ---------------------------")
    columnas_texto = [c for c in df.columns if df[c].dtype == 'object']
    print(f"Columnas tipo texto detectadas: {columnas_texto if columnas_texto else 'ninguna'}")

    for columna in columnas_texto:
        # Si el nombre de la columna contiene la palabra 'fecha', se saltea
        if "fecha" in columna.lower():
            print(f"'{columna}' contiene 'fecha', se omite del proceso.")
            continue

        original = df[columna].astype(str)

        # strip
        paso_strip = original.str.strip()
        cnt_strip = (original != paso_strip).sum()

        # eliminar caracteres invisibles
        paso_invis = paso_strip.str.replace(r'[\u200b\t\r\n]', '', regex=True)
        cnt_invis = (paso_strip != paso_invis).sum()

        # eliminar símbolos visibles
        paso_final = paso_invis.str.replace(r'[$€,%+\-"/\']', '', regex=True)
        cnt_replace = (paso_invis != paso_final).sum()

        # actualizar el DataFrame
        df[columna] = paso_final

        print(f"'{columna}': ajustadas con strip = {cnt_strip} | car. invisibles = {cnt_invis} | ajustadas con replace = {cnt_replace}")

    return df


# Aplicación a los tres conjuntos
ventas = normalizacion_texto(ventas_limpio, "Ventas")
clientes = normalizacion_texto(clientes_limpio, "Clientes")
marketing = normalizacion_texto(marketing_limpio, "Marketing")
# Out:
# --------------------------- Ventas ---------------------------
# Columnas tipo texto detectadas: ['producto', 'precio', 'fecha_venta', 'categoria']
# 'producto': ajustadas con strip = 0 | car. invisibles = 0 | ajustadas con replace = 0
# 'precio': ajustadas con strip = 0 | car. invisibles = 0 | ajustadas con replace = 3033
# 'fecha_venta' contiene 'fecha', se omite del proceso.
# 'categoria': ajustadas con strip = 0 | car. invisibles = 0 | ajustadas con replace = 0
#
# --------------------------- Clientes ---------------------------
# Columnas tipo texto detectadas: ['nombre', 'ciudad']
# 'nombre': ajustadas con strip = 0 | car. invisibles = 0 | ajustadas con replace = 14
# 'ciudad': ajustadas con strip = 0 | car. invisibles = 0 | ajustadas con replace = 0
#
# --------------------------- Marketing ---------------------------
# Columnas tipo texto detectadas: ['producto', 'canal', 'fecha_inicio', 'fecha_fin']
# ...

# %%
print("Marketing limpio")
display(marketing_limpio.head())
print("\nVentas limpio")
display(ventas_limpio.head())
print("\nClientes limpio")
display(clientes_limpio.head())
# Out:
# Marketing limpio
#    id_campanha         producto  canal  costo fecha_inicio   fecha_fin
# 0           74  Adorno de pared     TV   4.81   20/03/2024  03/05/2024
# 1           12           Tablet   RRSS   3.40   26/03/2024  13/05/2024
# 2           32  Lámpara de mesa  Email   5.54   28/03/2024  20/04/2024
# 3           21       Smartphone   RRSS   6.37   29/03/2024  16/05/2024
# 4           58         Alfombra  Email   4.25   31/03/2024  05/05/2024
# Ventas limpio
#    id_venta           producto  precio  cantidad fecha_venta  \
# 0       792  Cuadro decorativo   69.94       5.0  02/01/2024
# 1       811    Lámpara de mesa  105.10       5.0  02/01/2024
# 2      1156           Secadora   97.96       3.0  02/01/2024
# 3      1372           Heladera  114.35       8.0  02/01/2024
# 4      1546           Secadora  106.21       4.0  02/01/2024
#
#            categoria
# 0         Decoración
# 1         Decoración
# 2  Electrodomésticos
# 3  Electrodomésticos
# 4  Electrodomésticos
# ...

# %% [markdown]
# #### Corregir tipos de datos

# %%
def convertir_fechas(df, columnas_fecha, nombre_df, dayfirst=True):
    if not columnas_fecha:
        print("No se indicaron columnas de fecha.")
        return df

    for col in columnas_fecha:
        if col not in df.columns:
            print(f"(omitido) La columna '{col}' no existe en {nombre_df}.")
            continue

        total = len(df[col])
        df[col] = pd.to_datetime(df[col], errors='coerce', dayfirst=dayfirst)
        convertidas = df[col].notna().sum()
        nulas = df[col].isna().sum()
        print(f"{col}: {convertidas} convertidas | {nulas} no convertibles de {total}")

    return df

def convertir_a_float(df, columna, nombre_df):
    if columna not in df.columns:
        print(f"La columna '{columna}' no existe en {nombre_df}.")
        return df

    total = len(df)

    original = df[columna].copy()

    df[columna] = pd.to_numeric(df[columna], errors="coerce")

    convertidas = df[columna].notna().sum()
    nulas = df[columna].isna().sum()

    print(f"'{columna}' convertida a float: {convertidas} correctas | {nulas} no convertibles de {total}")

    if nulas > 0:
        print(f"Valores no convertibles:")
        print(original[df[columna].isna()].head(10))

    return df


print(f"--------------------------- Ventas ---------------------------")
ventas = convertir_a_float(ventas_limpio, "precio", "Ventas")
ventas = convertir_fechas(ventas_limpio, ["fecha_venta"], "Ventas")

print(f"\n--------------------------- Marketing ---------------------------")
marketing = convertir_fechas(marketing_limpio,["fecha_inicio","fecha_fin"], "Marketing")
# Out:
# --------------------------- Ventas ---------------------------
# 'precio' convertida a float: 3033 correctas | 2 no convertibles de 3035
# Valores no convertibles:
# 136    nan
# 139    nan
# Name: precio, dtype: object
# fecha_venta: 3035 convertidas | 0 no convertibles de 3035
#
# --------------------------- Marketing ---------------------------
# fecha_inicio: 90 convertidas | 0 no convertibles de 90
# fecha_fin: 90 convertidas | 0 no convertibles de 90

# %% [markdown]
# ### 5️⃣ Transformación de datos

# %%
def detectar_columna_producto(df, patrones=("producto", "id_producto", "sku", "articulo", "artículo")):
    for col in df.columns:
        nombre = str(col).lower()
        if any(p in nombre for p in patrones):
            return col
    return None

def agregar_rendimiento_por_producto(df_ventas, col_prod, col_precio="precio", col_cantidad="cantidad"):
    ventas_enriquecidas = df_ventas.assign(ingreso = df_ventas[col_precio] * df_ventas[col_cantidad])
    resumen = (
        ventas_enriquecidas
        .groupby(col_prod, as_index=False)
        .agg(
            ingreso_total = ('ingreso', 'sum'),
            unidades = (col_cantidad, 'sum'),
            precio_promedio = (col_precio, 'mean'),
            registros = ('ingreso', 'size')
        )
    )
    return resumen

def calcular_umbral_percentil(df_resumen, columna_metricas="ingreso_total", q=0.80):
    return df_resumen[columna_metricas].quantile(q)

def filtrar_alto_rendimiento(df_resumen, umbral_p80):
    df_top = (
        df_resumen
        .query("ingreso_total >= @umbral_p80", engine="python")
        .sort_values(by=["ingreso_total", "unidades"], ascending=[False, False], ignore_index=True)
    )
    return df_top


col_producto = detectar_columna_producto(ventas_limpio)
if col_producto is None:
    raise ValueError("No se encontró columna de producto. Renombrá una columna a 'producto' o similar.")

tabla_rendimiento = agregar_rendimiento_por_producto(
    ventas_limpio,
    col_prod=col_producto,
    col_precio="precio",
    col_cantidad="cantidad"
)

# Calcular el percentil 80
p80 = calcular_umbral_percentil(tabla_rendimiento, columna_metricas="ingreso_total", q=0.80)

# Filtrar productos de alto rendimiento
ventas_top = filtrar_alto_rendimiento(tabla_rendimiento, p80)

# Mostrar resultados
print(f"Columna de producto detectada: {col_producto}")
print(f"Umbral (percentil 80) de ingreso_total: {p80:,.2f}")
print("\n✅ Productos de alto rendimiento (top 20%):")
display(ventas_top.head(10))
# Out:
# Columna de producto detectada: producto
# Umbral (percentil 80) de ingreso_total: 53,430.91
#
# ✅ Productos de alto rendimiento (top 20%):
#             producto  ingreso_total  unidades  precio_promedio  registros
# 0    Lámpara de mesa       84699.15    1141.0        72.757348        181
# 1        Auriculares       76468.44     988.0        76.509252        147
# 2         Microondas       72562.89     912.0        79.176000        135
# 3           Cafetera       59669.54     766.0        78.904068        118
# 4         Smartphone       55615.64     677.0        81.812157        102
# 5  Cuadro decorativo       54297.60     726.0        74.578000        100

# %% [markdown]
# ### 6️⃣ Agregación

# %%
def detectar_columna(df, patrones):
    for c in df.columns:
        nombre = str(c).lower()
        if any(p in nombre for p in patrones):
            return c
    return None


col_categoria = detectar_columna(
    ventas_limpio,
    patrones=["categoria", "categoría", "categoria_producto", "rubro", "segmento"]
)
if col_categoria is None:
    raise ValueError("No se encontró una columna de categoría (p. ej., 'categoria' o 'rubro').")

if "ingreso" not in ventas_limpio.columns:
    base_cat = ventas_limpio.assign(ingreso = ventas_limpio["precio"] * ventas_limpio["cantidad"])
else:
    base_cat = ventas_limpio.copy()

resumen_categoria = (
    base_cat
    .groupby(by=col_categoria, as_index=False, dropna=False)
    .agg(
        ingreso_total = ("ingreso", "sum"),
        unidades = ("cantidad", "sum"),
        ventas = ("ingreso", "size"),
        precio_promedio = ("precio", "mean")
    )
    .sort_values(by="ingreso_total", ascending=False, na_position="last", ignore_index=True)
)

resumen_categoria = resumen_categoria.assign(
    ticket_promedio_por_venta = resumen_categoria["ingreso_total"] / resumen_categoria["ventas"]
)


print(f"Columna de categoría detectada: {col_categoria}")
print("Resumen por categoría (ordenado por ingreso_total):")
display(resumen_categoria.head(20))
# Out:
# Columna de categoría detectada: categoria
# Resumen por categoría (ordenado por ingreso_total):
#            categoria  ingreso_total  unidades  ventas  precio_promedio  \
# 0  Electrodomésticos      507671.41    6629.0    1008        76.446796
# 1        Electrónica      490557.00    6504.0    1012        75.378576
# 2         Decoración      484814.52    6571.0    1015        74.048846
#
#    ticket_promedio_por_venta
# 0                 503.642272
# 1                 484.740119
# 2                 477.649773
